# %% [markdown]
# <a href="https://colab.research.google.com/github/pagehi/Pascal-BTE-320/blob/main/BTE_320_In_Class_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales value ($): "))

cogs = 0.4 * sales
gross_profit = sales - cogs

print(f"Sales: {sales}$")
print(f"Cost of Goods Sold: {cogs}$")
print(f"Gross Profit: {gross_profit}$")
# Out:
# Enter sales value ($): 12000
# Sales: 12000.0$
# Cost of Goods Sold: 4800.0$
# Gross Profit: 7200.0$

# %%
sales = float(input("Enter sales value ($): "))
tax_rate = float(input("Enter tax rate (%): "))

cogs = 0.4 * sales
gross_profit = sales - cogs
taxes = gross_profit * tax_rate
net_income = gross_profit - taxes

print(f"Sales: {sales}$")
print(f"Cost of Goods Sold: {cogs}$")
print(f"Gross Profit: {gross_profit}$")
print(f"Taxes: {taxes}$")
print(f"Net Income: {net_income}$")
# Out:
# Enter sales value ($): 12000
# Enter tax rate (%): .3
# Sales: 12000.0$
# Cost of Goods Sold: 4800.0$
# Gross Profit: 7200.0$
# Taxes: 2160.0$
# Net Income: 5040.0$

# %%
number1 = float(input("number "))
number2 = float(input("number "))
math_operator = input ("Mathematical operator: (+,-,/,*,):")

if math_operator == "+":
  print(number1 + number2)
if math_operator == "-":
  print(number1 - number2)
if math_operator == "/":
  print(number1 / number2)
if math_operator == "*":
  print(number1 * number2)
# Out:
# number 3
# number 2
# Mathematical operator: (+,-,/,*,):+
# 5.0
